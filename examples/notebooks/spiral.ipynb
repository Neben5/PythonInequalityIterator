# %%
import numpy as np
import matplotlib as plt
from operations import *
# %run operations.py

# %%
state, equations = parse_system("system2")

# %%
plot_hemi(state['X'], color = 'g')
plot_hemi(state['Y'], color ='r')
plot_hemi(state['Z'], color = 'b')

# %%
def operate(state):
    newstate = apply_system(state, equations)
    plot_hemi(newstate['X'], color = 'g')
    plot_hemi(newstate['Y'], color ='r')
    plot_hemi(newstate['Z'], color = 'b')
    return newstate

# %%
state2 = operate(state)

# %%
state = operate(state)
