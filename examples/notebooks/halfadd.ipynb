# %%
import numpy as np
import matplotlib as plt
from operations import *
# %run operations.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib as plt
# ----> 3 from operations import *
#       4 get_ipython().run_line_magic('run', 'operations.py')
#
# ModuleNotFoundError: No module named 'operations'

# %%
from operations import parse_system


system, equations = parse_system("system")

# %%
equations
system
# Out:
# {'X': array([[0., 0.]]), 'Y': array([[1., 1.]])}

# %%
plot_hemi(system["X"], color = 'y')
plot_hemi(system["Y"], color='b')

# %%
system2 = apply_system(system, equations)
system2
plot_hemi(system2["X"], color = 'y')
plot_hemi(system2["Y"], color='b')

# %%
system3 = apply_system(system2, equations)
system3
plot_hemi(system3["X"], color = 'y')
plot_hemi(system3["Y"], color='b')

# %%
system4 = apply_system(system3, equations)
plot_hemi(system4["X"], color = 'y')
plot_hemi(system4["Y"], color='b')
hemi = system4["X"]
